# %%
import pandas as pd

info2023 = pd.read_csv('world.csv')

# %%
info2023
# Out:
#             ID iso_code  洲名   國家          日期    總確診數  新增確診數  七天移動平均新增確診數  \
# 0            1      AFG  亞洲  阿富汗  2020-02-24       5      5        0.000
# 1            2      AFG  亞洲  阿富汗  2020-02-25       5      0        0.000
# 2            3      AFG  亞洲  阿富汗  2020-02-26       5      0        0.000
# 3            4      AFG  亞洲  阿富汗  2020-02-27       5      0        0.000
# 4            5      AFG  亞洲  阿富汗  2020-02-28       5      0        0.000
# ...        ...      ...  ..  ...         ...     ...    ...          ...
# 187880  187881      ZWE  非洲  辛巴威  2022-07-02  255586      0       39.571
# 187881  187882      ZWE  非洲  辛巴威  2022-07-03  255586      0       33.000
# 187882  187883      ZWE  非洲  辛巴威  2022-07-04  255726    140       49.000
# 187883  187884      ZWE  非洲  辛巴威  2022-07-05  255755     29       53.143
# 187884  187885      ZWE  非洲  辛巴威  2022-07-06  255805     50       40.714
#
#         總死亡數  新增死亡數  ...  七天移動平均疫苗新增接種劑數  每百人接種疫苗劑數  每百人接種疫苗人數  疫情控管指數  \
# ...

# %%
df1 = info2023.query('國家 == "台灣"')

# %%
df2=df1.sort_values(by='新增確診數',ascending=False)

# %%
df2.iloc[:5]
# Out:
#             ID iso_code  洲名  國家          日期     總確診數   新增確診數  七天移動平均新增確診數  \
# 164835  164836      TWN  亞洲  台灣  2022-05-14   699824  128954    61607.857
# 164830  164831      TWN  亞洲  台灣  2022-05-09   397504  128935    37792.714
# 164848  164849      TWN  亞洲  台灣  2022-05-27  1735067   94796    82682.286
# 164840  164841      TWN  亞洲  台灣  2022-05-19  1070561   89420    71384.429
# 164846  164847      TWN  亞洲  台灣  2022-05-25  1558380   89361    82462.714
#
#         總死亡數  新增死亡數  ...  七天移動平均疫苗新增接種劑數  每百人接種疫苗劑數  每百人接種疫苗人數  疫情控管指數  \
# 164835  1049     81  ...         76312.0       0.00       0.00   26.85
# 164830   931     35  ...         87600.0     223.06      83.27   26.85
# 164848  1784    126  ...         83406.0     229.17      85.45   26.85
# 164840  1235     59  ...         75623.0     226.26      84.29   26.85
# 164846  1554     76  ...         71461.0     228.02      84.85   26.85
#
#             總人口數  中位數年紀  70歲以上人口比例   平均壽命  解除隔離數    解封指數
# ...

# %%
df3 = df1.set_index('日期')

# %%
df3
# Out:
#                 ID iso_code  洲名  國家     總確診數  新增確診數  七天移動平均新增確診數  總死亡數  新增死亡數  \
# 日期
# 2020-01-16  163987      TWN  亞洲  台灣        0      0        0.000     0      0
# 2020-01-17  163988      TWN  亞洲  台灣        0      0        0.000     0      0
# 2020-01-18  163989      TWN  亞洲  台灣        0      0        0.000     0      0
# 2020-01-19  163990      TWN  亞洲  台灣        0      0        0.000     0      0
# 2020-01-20  163991      TWN  亞洲  台灣        0      0        0.000     0      0
# ...            ...      ...  ..  ..      ...    ...          ...   ...    ...
# 2022-07-02  164885      TWN  亞洲  台灣  3837856  34807    37736.143  6868     96
# 2022-07-03  164886      TWN  亞洲  台灣  3870528  32672    36740.429  6956     88
# 2022-07-04  164887      TWN  亞洲  台灣  3893643  23115    35960.286  7025     69
# 2022-07-05  164888      TWN  亞洲  台灣  3929627  35984    34755.571  7128    103
# 2022-07-06  164889      TWN  亞洲  台灣  3964188  34561    33689.286  7223     95
#
# ...

# %%
df2 =  info2023.sort_values(by='新增確診數',ascending=False)

# %%
df2
# Out:
#             ID  iso_code   洲名       國家          日期       總確診數    新增確診數  \
# 185218  185219  OWID_WRL   全球       全球  2022-01-19  339436230  4080568
# 185220  185221  OWID_WRL   全球       全球  2022-01-21  347005476  3836622
# 185217  185218  OWID_WRL   全球       全球  2022-01-18  335355662  3760792
# 185225  185226  OWID_WRL   全球       全球  2022-01-26  363072962  3759476
# 185219  185220  OWID_WRL   全球       全球  2022-01-20  343168854  3732624
# ...        ...       ...  ...      ...         ...        ...      ...
# 142133  142134       LCA  北美洲     聖露西亞  2021-03-20       4113        0
# 142140  142141       LCA  北美洲     聖露西亞  2021-03-27       4191        0
# 142141  142142       LCA  北美洲     聖露西亞  2021-03-28       4191        0
# 142112  142113       LCA  北美洲     聖露西亞  2021-02-27       3356        0
# 60825    60826       PYF  大洋洲  法屬玻里尼西亞  2021-09-22      40178        0
#
#         七天移動平均新增確診數     總死亡數  新增死亡數  ...  七天移動平均疫苗新增接種劑數  每百人接種疫苗劑數  \
# ...

# %% [markdown]
# #'洲名','國家','日期','總確診數','新增確診數'
